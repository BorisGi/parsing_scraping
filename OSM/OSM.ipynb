# %%
import osmnx as ox
import networkx as nx

# %%
import pandas as pd

# %%
import arcgis
from arcgis.gis import GIS

# %%
import gdal, ogr

# %%
import osmium as osm

# %%
class OSMHandler(osm.SimpleHandler):
    def __init__(self):
        osm.SimpleHandler.__init__(self)
        self.osm_data = []

    def tag_inventory(self, elem, elem_type):
        for tag in elem.tags:
            self.osm_data.append([elem_type, 
                                   elem.id, 
                                   elem.version,
                                   elem.visible,
                                   pd.Timestamp(elem.timestamp),
                                   elem.uid,
                                   elem.user,
                                   elem.changeset,
                                   len(elem.tags),
                                   tag.k, 
                                   tag.v])

    def node(self, n):
        self.tag_inventory(n, "node")

    def way(self, w):
        self.tag_inventory(w, "way")

    def relation(self, r):
        self.tag_inventory(r, "relation")


osmhandler = OSMHandler()
# scan the input file and fills the handler list accordingly
osmhandler.apply_file("hungary-latest.osm")

# transform the list into a pandas DataFrame
data_colnames = ['type', 'id', 'version', 'visible', 'ts', 'uid',
                 'user', 'chgset', 'ntags', 'tagkey', 'tagvalue']
df_osm = pd.DataFrame(osmhandler.osm_data, columns=data_colnames)
#df_osm = tag_genome.sort_values(by=['type', 'id', 'ts'])

# %%
df_osm
# Out:
#              type        id  version  visible                        ts  uid  \
# 0            node    277309       11     True 2013-05-08 21:43:21+00:00    0
# 1            node   9516071        8     True 2020-04-09 06:46:18+00:00    0
# 2            node   9516177       10     True 2016-05-14 10:50:10+00:00    0
# 3            node   9519287        5     True 2017-05-04 16:23:37+00:00    0
# 4            node   9524847        5     True 2020-05-07 08:13:28+00:00    0
# ...           ...       ...      ...      ...                       ...  ...
# 8488448  relation  11637209        1     True 2020-09-17 15:52:26+00:00    0
# 8488449  relation  11637210        1     True 2020-09-17 15:52:26+00:00    0
# 8488450  relation  11637210        1     True 2020-09-17 15:52:26+00:00    0
# 8488451  relation  11637379        1     True 2020-09-17 16:25:43+00:00    0
# 8488452  relation  11637379        1     True 2020-09-17 16:25:43+00:00    0
#
#         user  chgset  ntags   tagkey         tagvalue
# 0                  0      1  highway  traffic_signals
# 1                  0      1  highway  traffic_signals
# 2                  0      1   source         crossing
# 3                  0      1  highway  traffic_signals
# 4                  0      1  highway  traffic_signals
# ...      ...     ...    ...      ...              ...
# 8488448            0      2     type     multipolygon
# 8488449            0      2  landuse         farmyard
# 8488450            0      2     type     multipolygon
# 8488451            0      2  landuse         farmyard
# 8488452            0      2     type     multipolygon
#
# [8488453 rows x 11 columns]

# %%
temp = df_osm[df_osm.tagvalue.str.contains('lenin', case=False)]

# %%
temp.shape
# Out:
# (140, 11)

# %%
temp.head(31)
# Out:
#          type          id  version  visible                        ts  uid  \
# 29119    node   286975602       15     True 2019-11-05 12:25:06+00:00    0
# 119544   node  1012276887        3     True 2018-07-01 19:50:46+00:00    0
# 305048   node  2142472603       10     True 2020-04-19 22:50:13+00:00    0
# 801719   node  3458289190        2     True 2020-07-19 19:20:22+00:00    0
# 818065   node  3459957886        1     True 2015-04-16 18:23:56+00:00    0
# 923995   node  3484823545        1     True 2015-04-28 18:49:34+00:00    0
# 1103466  node  3971846123        1     True 2016-01-27 19:25:50+00:00    0
# 1360734  node  4919394057        3     True 2020-06-13 06:13:50+00:00    0
# 1384530  node  4939178057        3     True 2017-10-06 15:09:46+00:00    0
# 2428759   way    22824586       15     True 2019-01-06 14:22:45+00:00    0
# 2428771   way    22824696       15     True 2016-03-26 17:37:01+00:00    0
# 2450026   way    25599208        8     True 2020-01-04 22:28:35+00:00    0
# 2500709   way    31862441        2     True 2019-02-19 11:04:13+00:00    0
# 2519235   way    35031444        6     True 2018-06-24 10:18:38+00:00    0
# 2519236   way    35031444        6     True 2018-06-24 10:18:38+00:00    0
# 2547734   way    41052438        6     True 2019-07-26 16:13:45+00:00    0
# 2549629   way    41425698       11     True 2018-12-30 17:45:39+00:00    0
# 2557624   way    42688563       17     True 2019-03-04 20:13:32+00:00    0
# 2571573   way    50226525        1     True 2010-02-13 14:41:15+00:00    0
# 2572260   way    50564558        9     True 2020-01-04 22:28:35+00:00    0
# 2572452   way    50564657        3     True 2020-01-04 22:28:35+00:00    0
# 2592103   way    56034645       16     True 2018-10-26 09:31:06+00:00    0
# 2682465   way    78800094        4     True 2014-03-04 14:18:05+00:00    0
# 2685239   way    79704826        3     True 2016-04-28 12:17:25+00:00    0
# 2694581   way    83522697        2     True 2012-09-05 15:26:44+00:00    0
# 2722673   way    93626304        6     True 2018-04-13 21:24:10+00:00    0
# 2722845   way    93639776        3     True 2016-05-05 12:48:04+00:00    0
# 2723235   way    93705683        3     True 2016-05-06 10:56:05+00:00    0
# 2738163   way    97397917        2     True 2018-01-30 10:57:13+00:00    0
# 2751884   way    99853689       10     True 2019-01-06 14:22:45+00:00    0
# 2757319   way   101178746        6     True 2019-05-09 12:20:50+00:00    0
#
#         user  chgset  ntags       tagkey                   tagvalue
# 29119              0     16     old_name                 Leninváros
# 119544             0      3     old_name                 Leninmajor
# 305048             0     10     old_name                 Leninváros
# 801719             0      6         name                      Lenin
# 818065             0      5         name          Lenin Tsz. I. üe.
# 923995             0      7         name  Nyírmeggyes, Lenin u. 65.
# 1103466            0      2         name      "Lenin-tanya' emlékmű
# 1360734            0      4         name                      Lenin
# 1384530            0      6         name       Lenin Café Gulag Pub
# 2428759            0      4     old_name                   Lenin út
# 2428771            0      3     old_name                   Lenin út
# 2450026            0      4     old_name                 Lenin utca
# 2500709            0      3     old_name                 Lenin utca
# 2519235            0      8     old_name                 Lenin utca
# 2519236            0      8  old_name:de              Lenin Strasse
# 2547734            0      4     old_name                 Lenin utca
# 2549629            0      4     old_name                   Lenin út
# 2557624            0      6     old_name                 Lenin utca
# 2571573            0      3         name                  Lenin tér
# 2572260            0      5     old_name                 Lenin utca
# 2572452            0      4     old_name                 Lenin utca
# 2592103            0      4     old_name                   Lenin út
# 2682465            0      3     old_name                 Lenin utca
# 2685239            0      3     old_name                 Lenin utca
# 2694581            0      3         name                 Lenin utca
# 2722673            0      4     old_name                 Lenin utca
# 2722845            0      3     old_name                 Lenin utca
# 2723235            0      3     old_name                 Lenin utca
# 2738163            0      3     old_name                 Lenin utca
# 2751884            0      4     old_name                   Lenin út
# 2757319            0     10     old_name                 Lenin utca
